# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Nana Qwasi\\Desktop\\Tutorials\\Programming\\Projects\\test.csv')

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
def survivors(age):
    if age >= 25:
        return "1"
    else:
        return "0"

# %%
survivors(27)
# Out:
# '1'

# %%
df['Survivors'] = df['Age'].apply(survivors)

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Survivors
# 0  34.5      0      0   330911   7.8292   NaN        Q         1
# 1  47.0      1      0   363272   7.0000   NaN        S         1
# 2  62.0      0      0   240276   9.6875   NaN        Q         1
# 3  27.0      0      0   315154   8.6625   NaN        S         1
# 4  22.0      1      1  3101298  12.2875   NaN        S         0

# %%
new_df = df[['PassengerId','Survivors']]

# %%
new_df
# Out:
#      PassengerId Survivors
# 0            892         1
# 1            893         1
# 2            894         1
# 3            895         1
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         1
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
new_df.to_excel('Titanic_project.xlsx',index=False)

# %%
new_df = pd.read_excel('Titanic_project.xlsx')

# %%
new_df.head()
# Out:
#    PassengerId  Survivors
# 0          892          1
# 1          893          1
# 2          894          1
# 3          895          1
# 4          896          0

# %%
#Concatenation

# %%
import numpy as np
import pandas as pd

# %%
data_one = {'A':['A0', 'A1', 'A2', 'A3'], 'B': ['B0', 'B1', 'B2', 'B3']}

# %%
data_two = {'C' : ['C0', 'C1', 'C2', 'C3'], 'D':['D0', 'D1', 'D2', 'D3']}

# %%
one = pd.DataFrame(data_one)

# %%
two = pd.DataFrame(data_two)

# %%
one
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
two
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
#Concatenating columns

# %%
pd.concat([one,two], axis=1)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
#Concatinating rows

# %%
two.columns = one.columns

# %%
two
# Out:
#     A   B
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
mydf = pd.concat([one,two],axis=0)

# %%
mydf.index = range(len(mydf))

# %%
mydf
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  C0  D0
# 5  C1  D1
# 6  C2  D2
# 7  C3  D3

# %%
data_a = {'Reg_id': ['1', '2', '3', '4'], 'name': ['Andrew', 'Bob', 'Charlie', 'David']}

# %%
data_b = {'log_id': ['1', '2', '3', '4'], 'name': ['Xavier', 'Andrew', 'Yolanda', 'Bob']}

# %%
registration = pd.DataFrame(data_a)

# %%
logins = pd.DataFrame(data_b)

# %%
registration
# Out:
#   Reg_id     name
# 0      1   Andrew
# 1      2      Bob
# 2      3  Charlie
# 3      4    David

# %%
logins
# Out:
#   log_id     name
# 0      1   Xavier
# 1      2   Andrew
# 2      3  Yolanda
# 3      4      Bob

# %%
#inner merge

# %%
pd.merge(registration,logins,how='inner',on='name')
# Out:
#   Reg_id    name log_id
# 0      1  Andrew      2
# 1      2     Bob      4

# %%
  #left merge

# %%
pd.merge(registration,logins,how='left',on='name')
# Out:
#   Reg_id     name log_id
# 0      1   Andrew      2
# 1      2      Bob      4
# 2      3  Charlie    NaN
# 3      4    David    NaN

# %%
pd.merge(registration,logins,how='right',on='name')
# Out:
#   Reg_id     name log_id
# 0    NaN   Xavier      1
# 1      1   Andrew      2
# 2    NaN  Yolanda      3
# 3      2      Bob      4

# %%
pd.merge(registration,logins,how='outer',on='name')
# Out:
#   Reg_id     name log_id
# 0      1   Andrew      2
# 1      2      Bob      4
# 2      3  Charlie    NaN
# 3      4    David    NaN
# 4    NaN   Xavier      1
# 5    NaN  Yolanda      3
