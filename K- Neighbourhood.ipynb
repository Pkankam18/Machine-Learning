# %%
#K-nearest neighbourhood

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\Nana Qwasi\\Documents\\Project\\Iris test data.csv')

# %%
df.head()
# Out:
#     SL   SW   PL   PW  Species
# 0  5.1  3.5  1.4  0.2        0
# 1  4.9  3.0  1.4  0.2        1
# 2  4.7  3.2  1.3  0.2        2
# 3  4.6  3.1  1.5  0.2        1
# 4  5.0  3.6  1.4  0.2        2

# %%
#Cell 23 and 24 deals with splitting the data into attributes and values
#I squeezed it because there was a combination of decimals and and a single value
array = df.values
squeezed_array = array.squeeze()

# %%
X =squeezed_array[:, :1]
y =squeezed_array[:, 1]

bins = [0, 0.5, 1]
categorical_array_np = np.digitize(y, bins)
#categorical_array_np = pd.cut(y, bins[0, 0.5, 1], labels=[0, 1])

print(categorical_array_np)
# Out:
# [3 3 3 3 3 3 3 3 3 3]

# %%
#Splitting the data into test and train data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
#Scaling and normalizing the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
#Training the K algorithm and making prediction
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor(n_neighbors=3)
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 from sklearn.neighbors import KNeighborsRegressor
#       3 regressor = KNeighborsRegressor(n_neighbors=3)
# ----> 4 regressor.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
y_pred = regressor.predict(X_test)

# %%
#Plotting the actual values vrs predicted values
plt.scatter(y_test,y_pred)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.title('Actual vrs Predicted values')
plt.show()

# %%
#Plot residuals(errors)
plt.scatter(y_test,y_pred)
plt.xlabel('Actual values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %%
#Convert continous values to class labels using a threshold
y_pred_class = (y_pred > 0.5).astype(int)

# %%
plt.plot(y_test,y_pred)
plt.xlabel('Actual values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %%
plt.hist(y_test,bins=10)
plt.xlabel('Actual values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()
